# %%
# !gdown --fuzzy https://drive.google.com/file/d/1OQumFjs4lpZtbVA8QyyiQkSDa_Ft6_-j/view?usp=sharing
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1OQumFjs4lpZtbVA8QyyiQkSDa_Ft6_-j
# From (redirected): https://drive.google.com/uc?id=1OQumFjs4lpZtbVA8QyyiQkSDa_Ft6_-j&confirm=t&uuid=cb80c178-3450-499d-9cd8-446b4448f108
# To: /content/dl_2_dataset.zip
# 100% 2.40G/2.40G [00:33<00:00, 71.4MB/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.9 MB/s eta 0:00:00
# ...

# %%
# !unzip dl_2_dataset.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: train/labels/0209-24_00940200.txt
#   inflating: train/labels/0209-7_00908400.txt
#   inflating: train/labels/0209-17_00870300.txt
#   inflating: train/labels/0209-13_00988500.txt
#   inflating: train/labels/0209-25_00972200.txt
#   inflating: train/labels/0209-26_00864100.txt
#   inflating: train/labels/0209-12_00866300.txt
#   inflating: train/labels/0209-7_01004800.txt
#   inflating: train/labels/0209-28_00875100.txt
#   inflating: train/labels/0209-24_00896800.txt
#   inflating: train/labels/0209-25_00924100.txt
#   inflating: train/labels/0209-27_01078500.txt
#   inflating: train/labels/0209-1_01205100.txt
#   inflating: train/labels/0209-1_01215000.txt
#   inflating: train/labels/0209-33_01116100.txt
#   inflating: train/labels/0209-35_00900600.txt
#   inflating: train/labels/0209-15_00913100.txt
#   inflating: train/labels/0209-24_00911300.txt
#   inflating: train/labels/0209-3_00971300.txt
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/yolo26l_first.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !rm -rf runs

# %%
print(model.model_name)
# Out:
# /content/yolo11l_second.pt

# %% [markdown]
# ## Процесс обучения очень простой

# %%
results = model.train(data = "/content/data.yaml", epochs=10, patience = 8, imgsz=726, cos_lr = True, name='lab2', lr0 = 1e-3, \
                      seed = 9999, dropout = 0.25, cutmix = 0.1, batch = 16, fliplr = 0.5, copy_paste = 0.2, mosaic = 0.1 )
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files

files.download('/content/runs/detect/lab2/weights/best.pt')

# %% [markdown]
# # Загружаем нашу лучшую модель

# %%
model = YOLO('runs/detect/lab2/weights/best.pt')

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1n8wfOqNIkjMDzKJQuFQv7LOaS60MSvDE/view?usp=sharing
# !unzip dl_2_test.zip
# !rm dl_2_test.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1n8wfOqNIkjMDzKJQuFQv7LOaS60MSvDE
# From (redirected): https://drive.google.com/uc?id=1n8wfOqNIkjMDzKJQuFQv7LOaS60MSvDE&confirm=t&uuid=426a0e7d-e552-48ae-a542-925079bc297e
# To: /content/dl_2_test.zip
# 100% 1.60G/1.60G [00:27<00:00, 59.1MB/s]
# Archive:  dl_2_test.zip
#    creating: test_images/
#   inflating: test_images/1.1_00-00-00-000.jpg
#   inflating: test_images/1.1_00-00-12-500.jpg
#   inflating: test_images/1.1_00-00-25-000.jpg
#   inflating: test_images/1.1_00-00-37-500.jpg
#   inflating: test_images/1.1_00-00-50-000.jpg
#   inflating: test_images/1.1_00-01-02-500.jpg
#   inflating: test_images/1.1_00-01-15-000.jpg
#   inflating: test_images/1.1_00-01-27-500.jpg
#   inflating: test_images/1.1_00-01-40-000.jpg
#   inflating: test_images/1.1_00-01-52-500.jpg
#   inflating: test_images/1.1_00-02-05-000.jpg
#   inflating: test_images/1.1_00-02-17-500.jpg
#   inflating: test_images/1.1_00-02-30-000.jpg
# ...

# %%
results = model.predict('/content/test_images', save_txt=True, save_conf=True, stream=True)
for r in results:
    pass
# Out:
# image 1/4454 /content/test_images/1.1_00-00-00-000.jpg: 416x736 1 customer, 60.4ms
# image 2/4454 /content/test_images/1.1_00-00-12-500.jpg: 416x736 2 customers, 1 staff, 29.9ms
# image 3/4454 /content/test_images/1.1_00-00-25-000.jpg: 416x736 2 customers, 29.8ms
# image 4/4454 /content/test_images/1.1_00-00-37-500.jpg: 416x736 2 customers, 29.8ms
# image 5/4454 /content/test_images/1.1_00-00-50-000.jpg: 416x736 2 customers, 1 staff, 29.9ms
# image 6/4454 /content/test_images/1.1_00-01-02-500.jpg: 416x736 2 customers, 22.7ms
# image 7/4454 /content/test_images/1.1_00-01-15-000.jpg: 416x736 1 customer, 20.7ms
# image 8/4454 /content/test_images/1.1_00-01-27-500.jpg: 416x736 1 customer, 20.7ms
# image 9/4454 /content/test_images/1.1_00-01-40-000.jpg: 416x736 1 staff, 20.8ms
# image 10/4454 /content/test_images/1.1_00-01-52-500.jpg: 416x736 1 customer, 20.6ms
# image 11/4454 /content/test_images/1.1_00-02-05-000.jpg: 416x736 1 customer, 20.6ms
# ...

# %% [markdown]
# # Собираем итоговое предсказание

# %%
from pathlib import Path
import json
import pandas as pd


def build_submission_from_solution_order(
    solution_csv: str,
    preds_dir: str,
    output_csv: str = "submission.csv",
    image_col: str = "image_name",
    boxes_col: str = "boxes",
    row_id_col: str = "id",
    require_score: bool = True,
    clamp_score: bool = True,
    keep_only_class: int | None = None,  # например 1, если нужны только строки класса 1; None = все классы
) -> None:
    """
    Builds submission.csv in EXACTLY the same image_name order as solution.csv.

    - Reads solution_csv, takes image_name column order as ground truth order.
    - For each image_name, looks for preds_dir/<stem>.txt
      where stem is Path(image_name).stem
    - If missing -> boxes=[]
    - Prediction txt lines: class xc yc w h score
    - Output boxes: JSON [[xc,yc,w,h,score], ...]
    """
    sol_path = Path(solution_csv)
    pdir = Path(preds_dir)

    if not sol_path.exists():
        raise FileNotFoundError(f"solution_csv not found: {sol_path}")
    if not pdir.exists() or not pdir.is_dir():
        raise FileNotFoundError(f"preds_dir not found or not a dir: {pdir}")

    sol = pd.read_csv(sol_path)
    if image_col not in sol.columns:
        raise ValueError(f"solution.csv must contain column '{image_col}'")

    # Keep original order from solution
    image_names = sol[image_col].astype(str).tolist()

    rows = []
    for idx, image_name in enumerate(image_names):
        stem = Path(image_name).stem
        pred_file = pdir / f"{stem}.txt"

        boxes = []
        if pred_file.exists():
            content = pred_file.read_text(encoding="utf-8", errors="replace").strip()
            if content:
                for ln in content.splitlines():
                    ln = ln.strip()
                    if not ln:
                        continue
                    parts = ln.split()
                    if require_score and len(parts) < 6:
                        continue
                    if len(parts) < 5:
                        continue

                    try:
                        cls = int(float(parts[0]))
                        if keep_only_class is not None and cls != keep_only_class:
                            continue

                        xc = float(parts[1])
                        yc = float(parts[2])
                        w = float(parts[3])
                        h = float(parts[4])
                        sc = float(parts[5]) if len(parts) >= 6 else 1.0
                    except ValueError:
                        continue

                    if clamp_score:
                        sc = 0.0 if sc < 0.0 else (1.0 if sc > 1.0 else sc)

                    boxes.append([xc, yc, w, h, sc])

        rows.append(
            {
                row_id_col: idx,
                image_col: image_name,  # EXACT match
                boxes_col: json.dumps(boxes, separators=(",", ":")),
            }
        )

    sub = pd.DataFrame(rows, columns=[row_id_col, image_col, boxes_col])
    sub.to_csv(output_csv, index=False)
    print(f"Saved: {output_csv} ({len(sub)} rows). Missing preds filled with [] in solution order.")

# %%
build_submission_from_solution_order(
    solution_csv=r"/content/sample_sub.csv",
    preds_dir=r"/content/runs/detect/predict/labels",
    output_csv="submission.csv",
    keep_only_class=1,
)
# Out:
# Saved: submission.csv (4454 rows). Missing preds filled with [] in solution order.
